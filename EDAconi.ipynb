# %%
miami= pd.read_parquet('FINAL_MIAMI_RESTOS_GOOGLE-2.parquet')

# %%
miami.head()
# Out:
#                                 name_x  \
# 0                   Honduras Nica Cafe
# 1                  Eight Bistro Lounge
# 2                                 Jrk!
# 4  MONALISA PIZERIA ITALIAN RESTAURANT
# 5                             Filtafry
#
#                                              address  \
# 0  Honduras Nica Cafe, 280 NW 79th St, Miami, FL ...
# 1  Eight Bistro Lounge, 9851 NW 58th St, Doral, F...
# 2  Jrk!, 19565 Biscayne Blvd. Ste. FH10, Aventura...
# 4  MONALISA PIZERIA ITALIAN RESTAURANT, 4753 SW 8...
# 5  Filtafry, 8865 SW 176th Terrace, Palmetto Bay,...
#
#                                  gmap_id description   latitude  longitude  \
# 0  0x88d9b176ea025e13:0x35d50186b9d6b2cc        None  25.847143 -80.202370
# 1  0x88d9bb7732788f7f:0xb16a74d70bd117e4        None  25.826451 -80.357219
# 2  0x88d9ad0792a901dd:0x4f3b06ee355b64ce        None  25.957618 -80.142596
# 4  0x88d9b7586c7923a5:0xa13568758d12b078        None  25.764368 -80.272756
# ...
