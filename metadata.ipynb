# %%
import pandas as pd
import numpy as np
import missingno as msxo
import glob
import folium
import plotly.express as px

# %%
df_1 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/metadata-sitios/1.json', lines= True)
df_1.head()
# Out:
#                name                                            address  \
# 0   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1      City Textile  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2      San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3      Nova Fabrics  Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4  Nobel Textile Co  Nobel Textile Co, 719 E 9th St, Los Angeles, C...
#
#                                  gmap_id description   latitude   longitude  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8        None  32.388300  -83.357100
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9        None  34.018891 -118.215290
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49        None  34.058092 -118.292130
# 3   0x80c2c89923b27a41:0x32041559418d447        None  34.023669 -118.232930
# 4  0x80c2c632f933b073:0xc31785961fe826a6        None  34.036694 -118.249421
#
#               category  avg_rating  num_of_reviews price  \
# ...

# %%
df_2 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/metadata-sitios/2.json', lines= True)
df_3 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/metadata-sitios/3.json', lines= True)
df_4 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/metadata-sitios/4.json', lines= True)
df_5 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/metadata-sitios/5.json', lines= True)
df_6 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/metadata-sitios/6.json', lines= True)
df_7 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/metadata-sitios/7.json', lines= True)
df_8 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/metadata-sitios/8.json', lines= True)
df_9 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/metadata-sitios/9.json', lines= True)
df_10 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/metadata-sitios/10.json', lines= True)
df_11 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/metadata-sitios/11.json', lines= True)

# %%
# Create a list to store your DataFrames
dfs = []

# Assuming you have DataFrames named df1 through df18
for i in range(1, 12):
    # Assuming the variable names are df1, df2, ..., df18
    df = globals()[f'df_{i}']
    dfs.append(df)

# Concatenate all the DataFrames in the list
merged_df = pd.concat(dfs, ignore_index=True)

# The resulting merged_df contains data from all the DataFrames

# %%
merged_df.to_csv('Metadata.csv', index=False, escapechar='\\')

# %%
merged_df.shape
# Out:
# (3025011, 15)

# %%
merged_df.columns
# Out:
# Index(['name', 'address', 'gmap_id', 'description', 'latitude', 'longitude',
#        'category', 'avg_rating', 'num_of_reviews', 'price', 'hours', 'MISC',
#        'state', 'relative_results', 'url'],
#       dtype='object')

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3025011 entries, 0 to 3025010
# Data columns (total 15 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   name              object
#  1   address           object
#  2   gmap_id           object
#  3   description       object
#  4   latitude          float64
#  5   longitude         float64
#  6   category          object
#  7   avg_rating        float64
#  8   num_of_reviews    int64
#  9   price             object
#  10  hours             object
#  11  MISC              object
#  12  state             object
#  13  relative_results  object
#  14  url               object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 346.2+ MB

# %%
metadata = pd.read_csv("C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/metadata-sitios/Metadata.csv")
metadata
# Out:
#                                    name  \
# 0                       Porter Pharmacy
# 1                          City Textile
# 2                          San Soo Dang
# 3                          Nova Fabrics
# 4                      Nobel Textile Co
# ...                                 ...
# 3025006                        Steak 48
# 3025007   Jack Mcnerney Chevrolet, Inc.
# 3025008  Central Ny Spay Neuter Assista
# 3025009                   Ok Feed Store
# 3025010              Crestview Crossing
#
#                                                    address  \
# 0        Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1        City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2        San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3        Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4        Nobel Textile Co, 719 E 9th St, Los Angeles, C...
# ...                                                    ...
# 3025006   Steak 48, 260 S Broad St, Philadelphia, PA 19102
# ...

# %%
reviews_fl= pd.read_csv("C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/Florida.csv")
reviews_fl.head()
# Out:
#         user_id              name           time  rating  \
# 0  1.014719e+20   Julie A. Gerber  1628003250740       1
# 1  1.154772e+20  Martin Sheffield  1595031217005       5
# 2  1.018050e+20      Brian Truett  1522924253567       5
# 3  1.063444e+20          Tina Sun  1467907819586       1
# 4  1.008751e+20      James Haynes  1480683415081       5
#
#                                                 text pics  \
# 0  Update: Their “reply” to my review amounted to...  NaN
# 1  He's a knowledgeable doctor but the way he run...  NaN
# 2  Best doctor I've ever had, I never wait to be ...  NaN
# 3  I was told he is a good doctor. I was trying t...  NaN
# 4  Takes the time to actually get to know his pat...  NaN
#
#                                                 resp  \
# 0  {'time': 1627042799532, 'text': 'Thank you for...
# 1  {'time': 1582464056733, 'text': 'Thank you for...
# 2                                                NaN
# ...

# %%
reviews_fl.shape
# Out:
# (2850000, 8)

# %%
reviews_fl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2850000 entries, 0 to 2849999
# Data columns (total 8 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   user_id  float64
#  1   name     object
#  2   time     int64
#  3   rating   int64
#  4   text     object
#  5   pics     object
#  6   resp     object
#  7   gmap_id  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 174.0+ MB

# %%
reviews_fl_completo = pd.merge(reviews_fl, metadata, on='gmap_id', how='inner')

# %%
reviews_fl_completo.columns
# Out:
# Index(['user_id', 'name_x', 'time', 'rating', 'text', 'pics', 'resp',
#        'gmap_id', 'name_y', 'address', 'description', 'latitude', 'longitude',
#        'category', 'avg_rating', 'num_of_reviews', 'price', 'hours', 'MISC',
#        'state', 'relative_results', 'url'],
#       dtype='object')

# %%
reviews_fl_completo.to_csv('Reviews_FL_completo.csv', index=False, escapechar='\\')

# %%
reviews_fl_completo = pd.read_csv("C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/metadata-sitios/reviews_FL_completo.csv")
reviews_fl_completo
# Out:
#               user_id            name_x           time  rating  \
# 0        1.014719e+20   Julie A. Gerber  1628003250740       1
# 1        1.014719e+20   Julie A. Gerber  1628003250740       1
# 2        1.154772e+20  Martin Sheffield  1595031217005       5
# 3        1.154772e+20  Martin Sheffield  1595031217005       5
# 4        1.018050e+20      Brian Truett  1522924253567       5
# ...               ...               ...            ...     ...
# 2869641  1.039909e+20    J. B. Oliveira  1503293272680       5
# 2869642  1.124797e+20            Adam K  1514763473117       5
# 2869643  1.103771e+20    English People  1531250213447       5
# 2869644  1.099194e+20           Shiva K  1532621720862       4
# 2869645  1.160935e+20  Tiago nascimento  1577461433361       4
#
#                                                       text pics  \
# 0        Update: Their “reply” to my review amounted to...  NaN
# 1        Update: Their “reply” to my review amounted to...  NaN
# ...

# %%
reviews_fl_completo.shape
# Out:
# (2869646, 22)

# %%
reviews_fl_completo.name_y.nunique()
# Out:
# 48997

# %%
#import folium
#import pandas as pd


# Create a map centered at a specific location (e.g., the first location)
#m = folium.Map(location=[reviews_fl["latitude"].iloc[0], reviews_fl["longitude"].iloc[0]], zoom_start=12)

# Iterate over the DataFrame and add markers for each location
#for index, row in reviews_fl.iterrows():
#    folium.Marker(
#        location=[row["latitude"], row["longitude"]],
#        popup=row["name_x"],
#        icon=folium.Icon(icon='cloud')
#    ).add_to(m)

# Display the map
#m

# %%
reviews_fl_completo.columns
# Out:
# Index(['user_id', 'name_x', 'time', 'rating', 'text', 'pics', 'resp',
#        'gmap_id', 'name_y', 'address', 'description', 'latitude', 'longitude',
#        'category', 'avg_rating', 'num_of_reviews', 'price', 'hours', 'MISC',
#        'state', 'relative_results', 'url'],
#       dtype='object')

# %%
pivot_table = reviews_fl_completo.pivot_table(index=['name_y', 'latitude', 'longitude'], values='gmap_id', aggfunc='count').reset_index()

# Rename the 'review_id' column to 'review_count' (optional)
pivot_table = pivot_table.rename(columns={'gmap_id': 'review_count'})

# Display the pivot table
pivot_table
# Out:
#                                                  name_y   latitude  longitude  \
# 0      "Public Library And Student Main Parking Garage"  26.081129 -80.242743
# 1                                  #1 Anytime Bail 24/7  29.197376 -82.163098
# 2                                              #1 Nails  28.755290 -81.356828
# 3                              #1 Stop Grocery & Market  30.345278 -81.675278
# 4                                   #1 auto liquidators  30.630575 -81.574254
# ...                                                 ...        ...        ...
# 59187                                💨 3J's Cigar Davie  26.063887 -80.257336
# 59188                           💨 3J's Cigar Lake Worth  26.618506 -80.159312
# 59189              💳 Credit360 Credit Repair Services 📈  25.595703 -80.363983
# 59190                            😁 White Smiles of Boca  26.350016 -80.090242
# 59191                             🥇 Nectar Lab Kava Bar  26.176886 -81.799163
#
#        review_count
# ...

# %%
pivot_table
# Out:
#                                                  name_y   latitude  longitude  \
# 0      "Public Library And Student Main Parking Garage"  26.081129 -80.242743
# 1                                  #1 Anytime Bail 24/7  29.197376 -82.163098
# 2                                              #1 Nails  28.755290 -81.356828
# 3                              #1 Stop Grocery & Market  30.345278 -81.675278
# 4                                   #1 auto liquidators  30.630575 -81.574254
# ...                                                 ...        ...        ...
# 59187                                💨 3J's Cigar Davie  26.063887 -80.257336
# 59188                           💨 3J's Cigar Lake Worth  26.618506 -80.159312
# 59189              💳 Credit360 Credit Repair Services 📈  25.595703 -80.363983
# 59190                            😁 White Smiles of Boca  26.350016 -80.090242
# 59191                             🥇 Nectar Lab Kava Bar  26.176886 -81.799163
#
#        review_count
# ...

# %%
reviews_fl_completo_with_text = reviews_fl_completo[reviews_fl_completo["text"].notna()]

# %%
reviews_fl_completo_with_text.name_x.value_counts()
# Out:
# A Google User     787
# Chris             281
# John              280
# Mike              279
# David             270
#                  ...
# Magaly Nelson       1
# magznolia           1
# Geraof geraof       1
# Martha Laynes       1
# English People      1
# Name: name_x, Length: 590197, dtype: int64
