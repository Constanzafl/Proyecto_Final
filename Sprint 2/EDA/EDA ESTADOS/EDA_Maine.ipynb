# %% [markdown]
# ## Lectura Maine

# %% [markdown]
# Lectura de los archivos de reviews de Maine

# %%
import pandas as pd
import numpy as np
import missingno as msxo
import glob
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %% [markdown]
# Lectura de archivos json de las reviews efectuadas en el estado de Maine . Voy a proceder a realizar la lectura y juntar dichos archivos, al tener todos la misma estructura es posible realizarlo mediante iteracion.

# %%
df_1 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maine\1.json', lines= True)
df_2 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maine\2.json', lines= True)
df_3 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maine\3.json', lines= True)
df_4 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maine\4.json', lines= True)
df_5 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maine\5.json', lines= True)
df_6 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maine\6.json', lines= True)
df_7 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maine\7.json', lines= True)
df_8 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maine\8.json', lines= True)

# %%
# Creo una lista para poder juntar todos los dataframes de los archivos en uno
dfs = []

# Itero entre cada uno de los dataframes para juntarlos en uno solo
for i in range(1, 9):
    
    df = globals()[f'df_{i}']
    dfs.append(df)


reviews_Maine = pd.concat(dfs, ignore_index=True)

# %%
# Vista primeros registros
reviews_Maine.head(3)
# Out:
#         user_id           name           time  rating  \
# 0  1.134399e+20  Steve Holland  1528823744253       4
# 1  1.074215e+20   Matthew Hall  1500129522343       2
# 2  1.038352e+20   Laura Oliver  1534025979137       1
#
#                                                 text  pics  resp  \
# 0  My friend and I played here today. played all ...  None  None
# 1  It literally pains me to give such a low revie...  None  None
# 2  DO NOT GO HERE!!! Seriously!! This was the mos...  None  None
#
#                                  gmap_id
# 0  0x4cb27993a61ab3e1:0xa6c6508fe8842ff0
# 1  0x4cb27993a61ab3e1:0xa6c6508fe8842ff0
# 2  0x4cb27993a61ab3e1:0xa6c6508fe8842ff0

# %%
# Miro cuantos registros tenemos en el dataframe unido

reviews_Maine.shape
# Out:
# (1123881, 8)

# %%
# Miro el tipo de información

reviews_Maine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1123881 entries, 0 to 1123880
# Data columns (total 8 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   user_id  1123881 non-null  float64
#  1   name     1123881 non-null  object
#  2   time     1123881 non-null  int64
#  3   rating   1123881 non-null  int64
#  4   text     614200 non-null   object
#  5   pics     32185 non-null    object
#  6   resp     95831 non-null    object
#  7   gmap_id  1123881 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 68.6+ MB

# %%
# Checkeo de nulos y su porcentaje

nulls_FL = pd.DataFrame(reviews_Maine.isnull().sum().sort_values(ascending = False))
nulls_FL["Porcentaje de nulos"] = round(nulls_FL/reviews_Maine.shape[0]*100,2)
nulls_FL.rename(columns = {0:"Nro nulos"})
# Out:
#          Nro nulos  Porcentaje de nulos
# pics       1091696                97.14
# resp       1028050                91.47
# text        509681                45.35
# user_id          0                 0.00
# name             0                 0.00
# time             0                 0.00
# rating           0                 0.00
# gmap_id          0                 0.00

# %%
columnas= ['pics', 'resp']
reviews_Maine= reviews_Maine.drop(columns=columnas)

# %%
reviews_Maine.columns
# Out:
# Index(['user_id', 'name', 'time', 'rating', 'text', 'gmap_id'], dtype='object')

# %%
reviews_Maine.dropna(inplace=True)

# %%
usuarios= reviews_Maine.user_id.nunique()

# %%
reviews= reviews_Maine.text.count()

# %%
print('En el estado de Maine, tenemos',usuarios,' usuarios que dejaron',reviews, 'reseñas.')
# Out:
# En el estado de Maine, tenemos 38037  usuarios que dejaron 614200 reseñas.

# %%
rating = reviews_Maine.rating.value_counts()

# Crear el gráfico de barras
plt.figure(figsize=(8, 6))
rating.plot(kind='bar', color='skyblue')

# Agregar etiquetas a las barras
for i, count in enumerate(rating):
    plt.text(i, count, str(count), ha='center', va='bottom')

# Configuración de etiquetas y título
plt.xlabel('Categoría de Review')
plt.ylabel('Cantidad')
plt.title('Conteo de ratings')

# Mostrar el gráfico
plt.show()

# %%
reviews_Maine['time'] = pd.to_datetime(reviews_Maine['time'], unit='ms').dt.strftime('%d/%m/%Y')

# %%
reviews_Maine['time'] = pd.to_datetime(reviews_Maine['time'], format='%d/%m/%Y')

reviews_Maine['year'] = reviews_Maine['time'].dt.year

# %%
min_date = reviews_Maine.time.min()
minimun_date = pd.to_datetime(min_date)
print(min_date)
print(minimun_date)
# Out:
# 2007-08-27 00:00:00
# 2007-08-27 00:00:00

# %%
max_date = reviews_Maine.time.max()
maximun_date = pd.to_datetime(max_date)
print(max_date)
print(maximun_date)
# Out:
# 2021-09-07 00:00:00
# 2021-09-07 00:00:00

# %%
conteo_por_año= reviews_Maine[['year', 'text']].groupby('year').count().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(data=conteo_por_año, x='year', y= 'text', color='red')
plt.xlabel('Año')
plt.ylabel('Cantidad de reviews')
plt.title('Reviews a lo largo de los años')
plt.show()

# %%
reviews_Maine["text"] = reviews_Maine["text"].astype(str)

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\flori\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\flori\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Assuming you have a DataFrame named "reviews_XXXXXXXXXXXXXXXXXX" with a "text" column
texto = " ".join(reviews_Maine["text"])

# Download NLTK data for tokenization and stopwords
nltk.download('punkt')
nltk.download('stopwords')

# Tokenization and removing stopwords
stop_words = set(stopwords.words("english"))
words = word_tokenize(texto)
words = [word.lower() for word in words if word.isalpha() and word.lower() not in stop_words]

# Join the words into a text string
texto_procesado = " ".join(words)

# Create the word cloud
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(texto_procesado)

# Visualize the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\flori\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\flori\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
