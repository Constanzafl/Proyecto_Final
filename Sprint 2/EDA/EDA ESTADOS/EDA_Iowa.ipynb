# %% [markdown]
# ## Lectura Iowa

# %% [markdown]
# Lectura de los archivos de reviews de Iowa

# %%
import pandas as pd
import numpy as np
import missingno as msxo
import glob
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %% [markdown]
# Lectura de archivos json de las reviews efectuadas en el estado de Iowa . Voy a proceder a realizar la lectura y juntar dichos archivos, al tener todos la misma estructura es posible realizarlo mediante iteracion.

# %%
df_1 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-Iowa/1.json', lines= True)
df_2 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-Iowa/2.json', lines= True)
df_3 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-Iowa/3.json', lines= True)
df_4 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-Iowa/4.json', lines= True)
df_5 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-Iowa/5.json', lines= True)
df_6 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-Iowa/6.json', lines= True)
df_7 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-Iowa/7.json', lines= True)
df_8 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-Iowa/8.json', lines= True)
df_9 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-Iowa/9.json', lines= True)
df_10 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-Iowa/10.json', lines= True)
df_11 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-Iowa/11.json', lines= True)
df_12 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-Iowa/12.json', lines= True)
df_13 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-Iowa/13.json', lines= True)
df_14 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-Iowa/14.json', lines= True)
df_15 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-Iowa/15.json', lines= True)
df_16 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-Iowa/16.json', lines= True)
df_17 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-Iowa/17.json', lines= True)
df_18 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-Iowa/18.json', lines= True)
# Out:
# C:\Users\tomas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\tomas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\tomas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# ...

# %%
# Creo una lista para poder juntar todos los dataframes de los archivos en uno
dfs = []

# Itero entre cada uno de los dataframes para juntarlos en uno solo
for i in range(1, 19):
    
    df = globals()[f'df_{i}']
    dfs.append(df)


reviews_Iowa = pd.concat(dfs, ignore_index=True)

# %%
# Vista primeros registros
reviews_Iowa.head(3)
# Out:
#         user_id             name           time  rating  \
# 0  1.154997e+20  Nicole Williams  1528935574441       5
# 1  1.100727e+20        Dmitriy N  1575832576112       5
# 2  1.170215e+20      Sue Dickman  1465139905809       5
#
#                                                 text  pics  \
# 0  I have found my new favorite nail shop. I love...  None
# 1  This place is awesome. Got my pedicure there a...  None
# 2  I love going to Polished Nails. Everyone is pr...  None
#
#                                                 resp  \
# 0          {'time': 1528950923185, 'text': 'Thanks'}
# 1  {'time': 1576094549338, 'text': 'Thanks , Dmit...
# 2                                               None
#
#                                  gmap_id
# 0  0x87ec238afdd8837b:0x2f43f2b12142bff5
# 1  0x87ec238afdd8837b:0x2f43f2b12142bff5
# 2  0x87ec238afdd8837b:0x2f43f2b12142bff5

# %%
# Miro cuantos registros tenemos en el dataframe unido

reviews_Iowa.shape
# Out:
# (2677684, 8)

# %%
# Miro el tipo de información

reviews_Iowa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2677684 entries, 0 to 2677683
# Data columns (total 8 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   user_id  float64
#  1   name     object
#  2   time     int64
#  3   rating   int64
#  4   text     object
#  5   pics     object
#  6   resp     object
#  7   gmap_id  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 163.4+ MB

# %%
# Checkeo de nulos y su porcentaje

nulls_FL = pd.DataFrame(reviews_Iowa.isnull().sum().sort_values(ascending = False))
nulls_FL["Porcentaje de nulos"] = round(nulls_FL/reviews_Iowa.shape[0]*100,2)
nulls_FL.rename(columns = {0:"Nro nulos"})
# Out:
#          Nro nulos  Porcentaje de nulos
# pics       2629534                98.20
# resp       2408942                89.96
# text       1295176                48.37
# user_id          0                 0.00
# name             0                 0.00
# time             0                 0.00
# rating           0                 0.00
# gmap_id          0                 0.00

# %%
reviews_Iowa.columns
# Out:
# Index(['user_id', 'name', 'time', 'rating', 'text', 'pics', 'resp', 'gmap_id'], dtype='object')

# %%
usuarios= reviews_Iowa.user_id.nunique()

# %%
reviews= reviews_Iowa.text.count()

# %%
print('En el estado de Iowa, tenemos',usuarios,' usuarios que dejaron',reviews, 'reseñas.')
# Out:
# En el estado de Iowa, tenemos 94907  usuarios que dejaron 1382508 reseñas.

# %%
rating = reviews_Iowa.rating.value_counts()

# Crear el gráfico de barras
plt.figure(figsize=(8, 6))
rating.plot(kind='bar', color='skyblue')

# Agregar etiquetas a las barras
for i, count in enumerate(rating):
    plt.text(i, count, str(count), ha='center', va='bottom')

# Configuración de etiquetas y título
plt.xlabel('Categoría de Review')
plt.ylabel('Cantidad')
plt.title('Conteo de ratings')

# Mostrar el gráfico
plt.show()

# %%
reviews_Iowa['time'] = pd.to_datetime(reviews_Iowa['time'], unit='ms').dt.strftime('%d/%m/%Y')

# %%
reviews_Iowa['time'] = pd.to_datetime(reviews_Iowa['time'], format='%d/%m/%Y')

reviews_Iowa['year'] = reviews_Iowa['time'].dt.year

# %%
min_date = reviews_Iowa.time.min()
minimun_date = pd.to_datetime(min_date)
print(min_date)
print(minimun_date)
# Out:
# 2008-01-16 00:00:00
# 2008-01-16 00:00:00

# %%
max_date = reviews_Iowa.time.max()
maximun_date = pd.to_datetime(max_date)
print(max_date)
print(maximun_date)
# Out:
# 2021-09-07 00:00:00
# 2021-09-07 00:00:00

# %%
conteo_por_año= reviews_Iowa[['year', 'text']].groupby('year').count().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(data=conteo_por_año, x='year', y= 'text', color='red')
plt.xlabel('Año')
plt.ylabel('Cantidad de reviews')
plt.title('Reviews a lo largo de los años')
plt.show()

# %%
reviews_Iowa["text"] = reviews_Iowa["text"].astype(str)
reviews_Iowa.dropna(subset=["text"], inplace=True)

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\tomas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\tomas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Assuming you have a DataFrame named "reviews_XXXXXXXXXXXXXXXXXX" with a "text" column
texto = " ".join(reviews_Iowa["text"])

# Download NLTK data for tokenization and stopwords
nltk.download('punkt')
nltk.download('stopwords')

# Tokenization and removing stopwords
stop_words = set(stopwords.words("english"))
words = word_tokenize(texto)
words = [word.lower() for word in words if word.isalpha() and word.lower() not in stop_words]

# Join the words into a text string
texto_procesado = " ".join(words)

# Create the word cloud
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(texto_procesado)

# Visualize the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\tomas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\tomas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
