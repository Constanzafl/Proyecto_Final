# %% [markdown]
# ## Lectura Maryland

# %% [markdown]
# Lectura de los archivos de reviews de Maryland

# %%
import pandas as pd
import numpy as np
import missingno as msxo
import glob
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %% [markdown]
# Lectura de archivos json de las reviews efectuadas en el estado de Maryland . Voy a proceder a realizar la lectura y juntar dichos archivos, al tener todos la misma estructura es posible realizarlo mediante iteracion.

# %%
df_1 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maryland\1.json', lines= True)
df_2 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maryland\2.json', lines= True)
df_3 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maryland\3.json', lines= True)
df_4 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maryland\4.json', lines= True)
df_5 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maryland\5.json', lines= True)
df_6 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maryland\6.json', lines= True)
df_7 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maryland\7.json', lines= True)
df_8 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maryland\8.json', lines= True)
df_9 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maryland\9.json', lines= True)
df_10 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maryland\10.json', lines= True)
df_11 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maryland\11.json', lines= True)
df_12 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maryland\12.json', lines= True)
df_13 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maryland\13.json', lines= True)
df_14 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maryland\14.json', lines= True)
df_15 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maryland\15.json', lines= True)
df_16 = pd.read_json(r'C:\Users\flori\Desktop\LOCAL\GOOGLE\Google Maps\reviews-estados\review-Maryland\16.json', lines= True)

# %%
# Creo una lista para poder juntar todos los dataframes de los archivos en uno
dfs = []

# Itero entre cada uno de los dataframes para juntarlos en uno solo
for i in range(1, 17):
    
    df = globals()[f'df_{i}']
    dfs.append(df)


reviews_Maryland = pd.concat(dfs, ignore_index=True)

# %%
# Vista primeros registros
reviews_Maryland.head(3)
# Out:
#         user_id      name           time  rating  \
# 0  1.162101e+20   Brian A  1528719383671       5
# 1  1.089905e+20  Marsha J  1556106162554       5
# 2  1.179088e+20      Noel  1531995775977       5
#
#                                                 text  pics  \
# 0  Every time I have been to this place I am in a...  None
# 1  Good pharmacy and fast service, majority of th...  None
# 2                              Awesome service here!  None
#
#                                                 resp  \
# 0                                               None
# 1  {'time': 1556236566548, 'text': 'Hi Marsha, th...
# 2                                               None
#
#                                  gmap_id
# 0  0x89b7a76096bdad0b:0x66e4be0af3dc1720
# 1  0x89b7a76096bdad0b:0x66e4be0af3dc1720
# 2  0x89b7a76096bdad0b:0x66e4be0af3dc1720

# %%
# Miro cuantos registros tenemos en el dataframe unido

reviews_Maryland.shape
# Out:
# (2400000, 8)

# %%
# Miro el tipo de información

reviews_Maryland.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400000 entries, 0 to 2399999
# Data columns (total 8 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   user_id  float64
#  1   name     object
#  2   time     int64
#  3   rating   int64
#  4   text     object
#  5   pics     object
#  6   resp     object
#  7   gmap_id  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 146.5+ MB

# %%
# Checkeo de nulos y su porcentaje

nulls_FL = pd.DataFrame(reviews_Maryland.isnull().sum().sort_values(ascending = False))
nulls_FL["Porcentaje de nulos"] = round(nulls_FL/reviews_Maryland.shape[0]*100,2)
nulls_FL.rename(columns = {0:"Nro nulos"})
# Out:
#          Nro nulos  Porcentaje de nulos
# pics       2336557                97.36
# resp       2095635                87.32
# text       1073525                44.73
# user_id          0                 0.00
# name             0                 0.00
# time             0                 0.00
# rating           0                 0.00
# gmap_id          0                 0.00

# %%
columnas= ['pics', 'resp']
reviews_Maryland= reviews_Maryland.drop(columns=columnas)

# %%
reviews_Maryland.columns
# Out:
# Index(['user_id', 'name', 'time', 'rating', 'text', 'gmap_id'], dtype='object')

# %%
reviews_Maryland.dropna(inplace=True)

# %%
usuarios= reviews_Maryland.user_id.nunique()

# %%
reviews= reviews_Maryland.text.count()

# %%
print('En el estado de Maryland, tenemos',usuarios,' usuarios que dejaron',reviews, 'reseñas.')
# Out:
# En el estado de Maryland, tenemos 169434  usuarios que dejaron 1326475 reseñas.

# %%
rating = reviews_Maryland.rating.value_counts()

# Crear el gráfico de barras
plt.figure(figsize=(8, 6))
rating.plot(kind='bar', color='skyblue')

# Agregar etiquetas a las barras
for i, count in enumerate(rating):
    plt.text(i, count, str(count), ha='center', va='bottom')

# Configuración de etiquetas y título
plt.xlabel('Categoría de Review')
plt.ylabel('Cantidad')
plt.title('Conteo de ratings')

# Mostrar el gráfico
plt.show()

# %%
reviews_Maryland['time'] = pd.to_datetime(reviews_Maryland['time'], unit='ms').dt.strftime('%d/%m/%Y')

# %%
reviews_Maryland['time'] = pd.to_datetime(reviews_Maryland['time'], format='%d/%m/%Y')

reviews_Maryland['year'] = reviews_Maryland['time'].dt.year

# %%
min_date = reviews_Maryland.time.min()
minimun_date = pd.to_datetime(min_date)
print(min_date)
print(minimun_date)
# Out:
# 1990-12-31 00:00:00
# 1990-12-31 00:00:00

# %%
max_date = reviews_Maryland.time.max()
maximun_date = pd.to_datetime(max_date)
print(max_date)
print(maximun_date)
# Out:
# 2021-09-08 00:00:00
# 2021-09-08 00:00:00

# %%
conteo_por_año= reviews_Maryland[['year', 'text']].groupby('year').count().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(data=conteo_por_año, x='year', y= 'text', color='red')
plt.xlabel('Año')
plt.ylabel('Cantidad de reviews')
plt.title('Reviews a lo largo de los años')
plt.show()

# %%
reviews_Maryland["text"] = reviews_Maryland["text"].astype(str)

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\flori\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\flori\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Assuming you have a DataFrame named "reviews_XXXXXXXXXXXXXXXXXX" with a "text" column
texto = " ".join(reviews_Maryland["text"])

# Download NLTK data for tokenization and stopwords
nltk.download('punkt')
nltk.download('stopwords')

# Tokenization and removing stopwords
stop_words = set(stopwords.words("english"))
words = word_tokenize(texto)
words = [word.lower() for word in words if word.isalpha() and word.lower() not in stop_words]

# Join the words into a text string
texto_procesado = " ".join(words)

# Create the word cloud
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(texto_procesado)

# Visualize the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\flori\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\flori\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
