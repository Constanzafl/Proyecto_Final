# %% [markdown]
# ## Lectura South Dakota

# %% [markdown]
# Lectura de los archivos de reviews de South Dakota

# %%
import pandas as pd
import numpy as np
import missingno as msxo
import glob
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %% [markdown]
# Lectura de archivos json de las reviews efectuadas en el estado de South Dakota. Voy a proceder a realizar la lectura y juntar dichos archivos, al tener todos la misma estructura es posible realizarlo mediante iteracion.

# %%
df_1 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-South_Dakota/1.json', lines= True)
df_2 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-South_Dakota/2.json', lines= True)
df_3 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-South_Dakota/3.json', lines= True)
df_4 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-South_Dakota/4.json', lines= True)
df_5 = pd.read_json('C:/Users/tomas/Desktop/DS - HENRY/00.LABS/3.PF/GOOGLE/reviews-estados/review-South_Dakota/5.json', lines= True)
# Out:
# C:\Users\tomas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\tomas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# C:\Users\tomas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\dtypes\astype.py:189: RuntimeWarning: invalid value encountered in cast
#   return values.astype(dtype, copy=copy)
# ...

# %%
# Creo una lista para poder juntar todos los dataframes de los archivos en uno
dfs = []

# Itero entre cada uno de los dataframes para juntarlos en uno solo
for i in range(1, 6):
    
    df = globals()[f'df_{i}']
    dfs.append(df)


reviews_South_Dakota = pd.concat(dfs, ignore_index=True)

# %%
# Vista primeros registros

reviews_South_Dakota.head(3)
# Out:
#         user_id               name           time  rating  \
# 0  1.035634e+20          Peri Gray  1516122675780       5
# 1  1.018250e+20        Suzy Berndt  1532922350314       5
# 2  1.087116e+20  Rosemary Red Legs  1530969093932       5
#
#                                     text  pics  resp  \
# 0  Great place to care for our children.  None  None
# 1                    Th sw y are so nice  None  None
# 2                  Went with my daughter  None  None
#
#                                  gmap_id
# 0  0x532af45db8f30779:0xd9be9359f1e56178
# 1  0x532af45db8f30779:0xd9be9359f1e56178
# 2  0x532af45db8f30779:0xd9be9359f1e56178

# %%
# Miro cuantos registros tenemos en el dataframe unido

reviews_South_Dakota.shape
# Out:
# (673048, 8)

# %%
# Miro el tipo de información

reviews_South_Dakota.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 673048 entries, 0 to 673047
# Data columns (total 8 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   user_id  673048 non-null  float64
#  1   name     673048 non-null  object
#  2   time     673048 non-null  int64
#  3   rating   673048 non-null  int64
#  4   text     347082 non-null  object
#  5   pics     15815 non-null   object
#  6   resp     83208 non-null   object
#  7   gmap_id  673048 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 41.1+ MB

# %%
# Checkeo de nulos y su porcentaje

nulls = pd.DataFrame(reviews_South_Dakota.isnull().sum().sort_values(ascending = False))
nulls["Porcentaje de nulos"] = round(nulls/reviews_South_Dakota.shape[0]*100,2)
nulls.rename(columns = {0:"Nro nulos"})
# Out:
#          Nro nulos  Porcentaje de nulos
# pics        657233                97.65
# resp        589840                87.64
# text        325966                48.43
# user_id          0                 0.00
# name             0                 0.00
# time             0                 0.00
# rating           0                 0.00
# gmap_id          0                 0.00

# %%
reviews_South_Dakota.columns
# Out:
# Index(['user_id', 'name', 'time', 'rating', 'text', 'pics', 'resp', 'gmap_id'], dtype='object')

# %%
reviews_South_Dakota.user_id.nunique()
# Out:
# 26037

# %% [markdown]
# En el estado de South Dakota, tenemos 26037 usuarios que emitieron 670K de reseñas.

# %%
rating = reviews_South_Dakota.rating.value_counts()

# Crear el gráfico de barras
plt.figure(figsize=(8, 6))
rating.plot(kind='bar', color='skyblue')

# Agregar etiquetas a las barras
for i, count in enumerate(rating):
    plt.text(i, count, str(count), ha='center', va='bottom')

# Configuración de etiquetas y título
plt.xlabel('Categoría de Review')
plt.ylabel('Cantidad')
plt.title('Conteo de ratings')

# Mostrar el gráfico
plt.show()

# %%
reviews_South_Dakota['time'] = pd.to_datetime(reviews_South_Dakota['time'], unit='ms').dt.strftime('%d/%m/%Y')

# %%
reviews_South_Dakota['time'] = pd.to_datetime(reviews_South_Dakota['time'], format='%d/%m/%Y')

reviews_South_Dakota['year'] = reviews_South_Dakota['time'].dt.year

# %%
min_date = reviews_South_Dakota.time.min()
minimun_date = pd.to_datetime(min_date)
print(min_date)
print(minimun_date)
# Out:
# 2008-06-12 00:00:00
# 2008-06-12 00:00:00

# %%
max_date = reviews_South_Dakota.time.max()
maximun_date = pd.to_datetime(max_date)
print(max_date)
print(maximun_date)
# Out:
# 2021-09-07 00:00:00
# 2021-09-07 00:00:00

# %%
conteo_por_año= reviews_South_Dakota[['year', 'text']].groupby('year').count().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(data=conteo_por_año, x='year', y= 'text', color='red')
plt.xlabel('Año')
plt.ylabel('Cantidad de reviews')
plt.title('Reviews a lo largo de los años')
plt.show()

# %%
reviews_South_Dakota["text"] = reviews_South_Dakota["text"].astype(str)
reviews_South_Dakota.dropna(subset=["text"], inplace=True)

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\tomas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\tomas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Assuming you have a DataFrame named "reviews_XXXXXXXXXXXXXXXXXX" with a "text" column
texto = " ".join(reviews_South_Dakota["text"])

# Download NLTK data for tokenization and stopwords
nltk.download('punkt')
nltk.download('stopwords')

# Tokenization and removing stopwords
stop_words = set(stopwords.words("english"))
words = word_tokenize(texto)
words = [word.lower() for word in words if word.isalpha() and word.lower() not in stop_words]

# Join the words into a text string
texto_procesado = " ".join(words)

# Create the word cloud
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(texto_procesado)

# Visualize the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\tomas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\tomas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
